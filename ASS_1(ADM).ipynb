# %% [markdown]
# <a href="https://colab.research.google.com/github/VARSHITHA-DARMINI/ADM/blob/main/ASS_1(ADM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('employee_data.csv')
print("Original Dataset:")
print(df)
# Out:
# Original Dataset:
#     Employee_ID   Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  50.0  108953.0               9.0                   36
# 1          1002  36.0   82995.0               8.0                   59
# 2          1003  29.0   70757.0               2.0                   30
# 3          1004  42.0   39692.0               1.0                   30
# 4          1005  40.0   75758.0               7.0                   54
# 5          1006  44.0  102409.0               7.0                   56
# 6          1007  32.0       NaN               NaN                   59
# 7          1008  32.0   95697.0               5.0                   54
# 8          1009  45.0   67065.0               3.0                   49
# 9          1010  57.0       NaN               8.0                   42
# 10         1011  45.0   41534.0               6.0                   38
# 11         1012   NaN   70397.0               NaN                   32
# ...

# %%
df.isna()
# Out:
#     Employee_ID    Age  Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0         False  False   False             False                False
# 1         False  False   False             False                False
# 2         False  False   False             False                False
# 3         False  False   False             False                False
# 4         False  False   False             False                False
# 5         False  False   False             False                False
# 6         False  False    True              True                False
# 7         False  False   False             False                False
# 8         False  False   False             False                False
# 9         False  False    True             False                False
# 10        False  False   False             False                False
# 11        False   True   False              True                False
# ...

# %%
df.isnull().sum()
# Out:
# Employee_ID             0
# Age                     5
# Salary                  5
# Job_Satisfaction       10
# Work_Hours_Per_Week     0
# dtype: int64

# %%
df['Age'].mean()
# Out:
# 39.17777777777778

# %%
df['Salary'].mean()
# Out:
# 72349.2

# %%
df['Job_Satisfaction'].mean()
# Out:
# 5.55

# %%
df['Job_Satisfaction'].mode()
# Out:
# 0    7.0
# Name: Job_Satisfaction, dtype: float64

# %%
df['Salary'].mode()
# Out:
# 0      31016.0
# 1      32568.0
# 2      32695.0
# 3      33561.0
# 4      35258.0
# 5      39268.0
# 6      39692.0
# 7      41534.0
# 8      42185.0
# 9      42666.0
# 10     43986.0
# 11     52662.0
# 12     53247.0
# 13     54300.0
# 14     56854.0
# 15     63159.0
# 16     67065.0
# 17     68044.0
# 18     68660.0
# 19     69099.0
# 20     69504.0
# 21     70397.0
# 22     70757.0
# 23     70774.0
# 24     75758.0
# 25     78190.0
# 26     78984.0
# 27     81214.0
# 28     82251.0
# 29     82995.0
# 30     85591.0
# 31     91228.0
# 32     91858.0
# 33     92592.0
# 34     93704.0
# 35     94505.0
# 36     95697.0
# 37     97563.0
# 38    102409.0
# 39    104065.0
# 40    108953.0
# 41    112798.0
# 42    116807.0
# 43    119789.0
# 44    119812.0
# Name: Salary, dtype: float64

# %%
df['Age'].mode()
# Out:
# 0    23.0
# Name: Age, dtype: float64

# %%
df['Age'].median()
# Out:
# 39.0

# %%
df['Salary'].median()
# Out:
# 70757.0

# %%
df['Job_Satisfaction'].median()
# Out:
# 6.0

# %%
df['Job_Satisfaction'].fillna(df['Job_Satisfaction'].mean(), inplace=True)
# Out:
# <ipython-input-16-69ada0b06065>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Job_Satisfaction'].fillna(df['Job_Satisfaction'].mean(), inplace=True)

# %%
df['Job_Satisfaction'] = df['Job_Satisfaction'].fillna(df['Job_Satisfaction'].mean())

# %%
df['Age'] =df['Age'].fillna(df['Age'].mean())

# %%
df['Salary'] =df['Salary'].fillna(df['Salary'].mean())

# %%
df
# Out:
#     Employee_ID        Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  50.000000  108953.0              9.00                   36
# 1          1002  36.000000   82995.0              8.00                   59
# 2          1003  29.000000   70757.0              2.00                   30
# 3          1004  42.000000   39692.0              1.00                   30
# 4          1005  40.000000   75758.0              7.00                   54
# 5          1006  44.000000  102409.0              7.00                   56
# 6          1007  32.000000   72349.2              5.55                   59
# 7          1008  32.000000   95697.0              5.00                   54
# 8          1009  45.000000   67065.0              3.00                   49
# 9          1010  57.000000   72349.2              8.00                   42
# 10         1011  45.000000   41534.0              6.00                   38
# ...

# %%
print("Dataset after handling missing values:")
print(df)
# Out:
# Dataset after handling missing values:
#     Employee_ID        Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  50.000000  108953.0              9.00                   36
# 1          1002  36.000000   82995.0              8.00                   59
# 2          1003  29.000000   70757.0              2.00                   30
# 3          1004  42.000000   39692.0              1.00                   30
# 4          1005  40.000000   75758.0              7.00                   54
# 5          1006  44.000000  102409.0              7.00                   56
# 6          1007  32.000000   72349.2              5.55                   59
# 7          1008  32.000000   95697.0              5.00                   54
# 8          1009  45.000000   67065.0              3.00                   49
# 9          1010  57.000000   72349.2              8.00                   42
# 10         1011  45.000000   41534.0              6.00                   38
# ...

# %% [markdown]
# Perform Feature Scaling
#
# 1. Using MinMaxScaler (Built-in Library) Min-Max Scaling transforms data to a range of [0, 1]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
df[['Age', 'Salary']] = scaler.fit_transform(df[['Age', 'Salary']])

# %%
df['Job_Satisfaction'] = (df['Job_Satisfaction'] - df['Job_Satisfaction'].min()) / (df['Job_Satisfaction'].max() - df['Job_Satisfaction'].min())

# %% [markdown]
# 2. Standard Scaling (Z-Score Normalization) Standard Scaling transforms features to have a mean of 0 and a standard deviation of 1.

# %%
from sklearn.preprocessing import StandardScaler

s_scaler = StandardScaler()
df[['Work_Hours_Per_Week']] = s_scaler.fit_transform(df[[ 'Work_Hours_Per_Week']])
df['Work_Hours_Per_Week']
# Out:
# 0    -0.905969
# 1     1.483629
# 2    -1.529343
# 3    -1.529343
# 4     0.964151
# 5     1.171942
# 6     1.483629
# 7     0.964151
# 8     0.444673
# 9    -0.282596
# 10   -0.698178
# 11   -1.321551
# 12   -0.905969
# 13   -1.009865
# 14   -0.802074
# 15    1.171942
# 16   -0.698178
# 17    1.483629
# 18   -1.113760
# 19   -1.529343
# 20    0.340777
# 21   -0.594283
# 22   -0.386491
# 23    0.860255
# 24   -0.074805
# 25    1.171942
# 26    0.652464
# 27    0.860255
# 28   -0.698178
# 29    0.444673
# 30    0.132986
# 31    1.483629
# 32    0.132986
# 33    1.068046
# 34    0.444673
# 35   -0.386491
# 36    1.483629
# 37   -0.905969
# 38   -1.425447
# 39   -1.321551
# 40    0.132986
# 41   -1.113760
# 42    0.132986
# 43    0.860255
# 44    0.132986
# 45    1.171942
# 46    0.132986
# 47   -1.425447
# 48   -1.425447
# 49    1.275837
# Name: Work_Hours_Per_Week, dtype: float64

# %%
df[['Job_Satisfaction']] = s_scaler.fit_transform(df[[ 'Job_Satisfaction']])
df['Job_Satisfaction']
# Out:
# 0     1.432782e+00
# 1     1.017483e+00
# 2    -1.474311e+00
# 3    -1.889610e+00
# 4     6.021836e-01
# 5     6.021836e-01
# 6    -5.329071e-17
# 7    -2.284145e-01
# 8    -1.059012e+00
# 9     1.017483e+00
# 10    1.868846e-01
# 11   -5.329071e-17
# 12   -5.329071e-17
# 13   -1.889610e+00
# 14   -1.059012e+00
# 15   -2.284145e-01
# 16   -1.059012e+00
# 17   -1.889610e+00
# 18   -2.284145e-01
# 19    1.848081e+00
# 20    6.021836e-01
# 21    6.021836e-01
# 22   -5.329071e-17
# 23    1.432782e+00
# 24    1.848081e+00
# 25   -5.329071e-17
# 26   -1.059012e+00
# 27    6.021836e-01
# 28   -1.889610e+00
# 29   -6.437135e-01
# 30   -6.437135e-01
# 31   -5.329071e-17
# 32    6.021836e-01
# 33    6.021836e-01
# 34   -5.329071e-17
# 35   -6.437135e-01
# 36    6.021836e-01
# 37   -5.329071e-17
# 38   -1.059012e+00
# 39    1.868846e-01
# 40   -1.474311e+00
# 41    1.848081e+00
# 42    1.432782e+00
# 43   -2.284145e-01
# 44    1.868846e-01
# 45   -6.437135e-01
# 46   -5.329071e-17
# ...

# %% [markdown]
# b) Manually Implementing Standard Scaling Z-Score formula:

# %%
df['Job_Satisfaction'] = (df['Job_Satisfaction'] - df['Job_Satisfaction'].mean()) / df['Job_Satisfaction'].std()
df
# Out:
#     Employee_ID       Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  0.750000  0.877708      1.418381e+00            -0.905969
# 1          1002  0.361111  0.585375      1.007256e+00             1.483629
# 2          1003  0.166667  0.447554     -1.459494e+00            -1.529343
# 3          1004  0.527778  0.097707     -1.870619e+00            -1.529343
# 4          1005  0.472222  0.503874      5.961313e-01             0.964151
# 5          1006  0.583333  0.804011      5.961313e-01             1.171942
# 6          1007  0.250000  0.465485     -9.703013e-17             1.483629
# 7          1008  0.250000  0.728422     -2.261188e-01             0.964151
# 8          1009  0.611111  0.405975     -1.048369e+00             0.444673
# 9          1010  0.944444  0.465485      1.007256e+00            -0.282596
# 10         1011  0.611111  0.118451      1.850063e-01            -0.698178
# ...

# %%
df['Work_Hours_Per_Week'] = (df['Work_Hours_Per_Week'] - df['Work_Hours_Per_Week'].mean()) / df['Work_Hours_Per_Week'].std()
df
# Out:
#     Employee_ID       Age    Salary  Job_Satisfaction  Work_Hours_Per_Week
# 0          1001  0.750000  0.877708      1.418381e+00            -0.896864
# 1          1002  0.361111  0.585375      1.007256e+00             1.468717
# 2          1003  0.166667  0.447554     -1.459494e+00            -1.513972
# 3          1004  0.527778  0.097707     -1.870619e+00            -1.513972
# 4          1005  0.472222  0.503874      5.961313e-01             0.954461
# 5          1006  0.583333  0.804011      5.961313e-01             1.160163
# 6          1007  0.250000  0.465485     -9.703013e-17             1.468717
# 7          1008  0.250000  0.728422     -2.261188e-01             0.954461
# 8          1009  0.611111  0.405975     -1.048369e+00             0.440204
# 9          1010  0.944444  0.465485      1.007256e+00            -0.279756
# 10         1011  0.611111  0.118451      1.850063e-01            -0.691161
# ...
